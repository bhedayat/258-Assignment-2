# %% [markdown]
# <br/>
# ### Third level model - Predict Among Non-US Countries
#
# Planned Model:  (NDF | (US | Not US))
#
# First level predicts {'NDF' vs Non-NDF}
#
# Second level predicts {'US' vs Not-US}
#
# Third level predicts which of the Non-US countries: {'AU', 'CA', 'DE', 'ES', 'FR', 'GB', 'IT', 'NL', 'PT', 'other'}

# %% [markdown]
# #### Imports and Read in data

# %%
import numpy as np
import pandas as pd
from sklearn.utils import shuffle
import datetime
import matplotlib.pyplot as plt
from collections import defaultdict
# %matplotlib inline

# %%
train_users_path = '../../Data/train_users_2.csv'
train_users = pd.read_csv(train_users_path)
#train_users.ix[train_users['country_destination'] != 'NDF', 'country_destination'] = 'NonNDF'
print(len(train_users))
train_users.head()
# Out:
# 213451
#            id date_account_created  timestamp_first_active date_first_booking  \
# 0  gxn3p5htnn           2010-06-28          20090319043255                NaN
# 1  820tgsjxq7           2011-05-25          20090523174809                NaN
# 2  4ft3gnwmtx           2010-09-28          20090609231247         2010-08-02
# 3  bjjt8pjhuk           2011-12-05          20091031060129         2012-09-08
# 4  87mebub9p4           2010-09-14          20091208061105         2010-02-18
#
#       gender   age signup_method  signup_flow language affiliate_channel  \
# 0  -unknown-   NaN      facebook            0       en            direct
# 1       MALE  38.0      facebook            0       en               seo
# 2     FEMALE  56.0         basic            3       en            direct
# 3     FEMALE  42.0      facebook            0       en            direct
# 4  -unknown-  41.0         basic            0       en            direct
#
#   affiliate_provider first_affiliate_tracked signup_app first_device_type  \
# 0             direct               untracked        Web       Mac Desktop
# 1             google               untracked        Web       Mac Desktop
# 2             direct               untracked        Web   Windows Desktop
# 3             direct               untracked        Web       Mac Desktop
# 4             direct               untracked        Web       Mac Desktop
#
#   first_browser country_destination
# 0        Chrome                 NDF
# 1        Chrome                 NDF
# 2            IE                  US
# 3       Firefox               other
# 4        Chrome                  US

# %%
sessions_path = '../../Data/sessions.csv'
sessions = pd.read_csv(sessions_path)
print(len(sessions))
sessions.head()
# Out:
# 10567737
#       user_id          action action_type        action_detail  \
# 0  d1mm9tcy42          lookup         NaN                  NaN
# 1  d1mm9tcy42  search_results       click  view_search_results
# 2  d1mm9tcy42          lookup         NaN                  NaN
# 3  d1mm9tcy42  search_results       click  view_search_results
# 4  d1mm9tcy42          lookup         NaN                  NaN
#
#        device_type  secs_elapsed
# 0  Windows Desktop         319.0
# 1  Windows Desktop       67753.0
# 2  Windows Desktop         301.0
# 3  Windows Desktop       22141.0
# 4  Windows Desktop         435.0

# %%
test_path = '../../Data/test_users.csv'
test_users = pd.read_csv(test_path)
print(len(test_users))
test_users.head()
# Out:
# 62096
#            id date_account_created  timestamp_first_active  \
# 0  5uwns89zht           2014-07-01          20140701000006
# 1  jtl0dijy2j           2014-07-01          20140701000051
# 2  xx0ulgorjt           2014-07-01          20140701000148
# 3  6c6puo6ix0           2014-07-01          20140701000215
# 4  czqhjk3yfe           2014-07-01          20140701000305
#
#    date_first_booking     gender   age signup_method  signup_flow language  \
# 0                 NaN     FEMALE  35.0      facebook            0       en
# 1                 NaN  -unknown-   NaN         basic            0       en
# 2                 NaN  -unknown-   NaN         basic            0       en
# 3                 NaN  -unknown-   NaN         basic            0       en
# 4                 NaN  -unknown-   NaN         basic            0       en
#
#   affiliate_channel affiliate_provider first_affiliate_tracked signup_app  \
# 0            direct             direct               untracked      Moweb
# 1            direct             direct               untracked      Moweb
# 2            direct             direct                  linked        Web
# 3            direct             direct                  linked        Web
# 4            direct             direct               untracked        Web
#
#   first_device_type  first_browser
# 0            iPhone  Mobile Safari
# 1            iPhone  Mobile Safari
# 2   Windows Desktop         Chrome
# 3   Windows Desktop             IE
# 4       Mac Desktop         Safari

# %%
countries_path = '../../Data/countries.csv'
countries = pd.read_csv(countries_path)
#train_users.ix[train_users['country_destination'] != 'NDF', 'country_destination'] = 'NonNDF'
print(len(countries))
countries
# Out:
# 10
#   country_destination  lat_destination  lng_destination  distance_km  \
# 0                  AU       -26.853388       133.275160   15297.7440
# 1                  CA        62.393303       -96.818146    2828.1333
# 2                  DE        51.165707        10.452764    7879.5680
# 3                  ES        39.896027        -2.487694    7730.7240
# 4                  FR        46.232193         2.209667    7682.9450
# 5                  GB        54.633220        -3.432277    6883.6590
# 6                  IT        41.873990        12.564167    8636.6310
# 7                  NL        52.133057         5.295250    7524.3203
# 8                  PT        39.553444        -7.839319    7355.2534
# 9                  US        36.966427       -95.844030       0.0000
#
#    destination_km2 destination_language   language_levenshtein_distance
# 0        7741220.0                   eng                           0.00
# 1        9984670.0                   eng                           0.00
# 2         357022.0                   deu                          72.61
# 3         505370.0                   spa                          92.25
# 4         643801.0                   fra                          92.06
# 5         243610.0                   eng                           0.00
# 6         301340.0                   ita                          89.40
# 7          41543.0                   nld                          63.22
# 8          92090.0                   por                          95.45
# 9        9826675.0                   eng                           0.00

# %%
destLangToLangMap = defaultdict(str)

destLangtoLangMap = { 'eng':'en', 'deu':'de', 'spa':'es', 'fra':'fr', 'ita':'it', 'por':'pt', 'nld':'nl' }

# %%
countries_path = '../../Data/age_gender_bkts.csv'
countries = pd.read_csv(countries_path)
#train_users.ix[train_users['country_destination'] != 'NDF', 'country_destination'] = 'NonNDF'
print(len(countries))
countries[countries['country_destination']=='CA']
# Out:
# 420
#    age_bucket country_destination  gender  population_in_thousands    year
# 42      75-79                  CA  female                    530.0  2015.0
# 43      75-79                  CA    male                    446.0  2015.0
# 44      35-39                  CA  female                   1192.0  2015.0
# 45      25-29                  CA  female                   1220.0  2015.0
# 46      95-99                  CA    male                     13.0  2015.0
# 47      40-44                  CA    male                   1179.0  2015.0
# 48      30-34                  CA  female                   1240.0  2015.0
# 49      60-64                  CA  female                   1142.0  2015.0
# 50      55-59                  CA    male                   1287.0  2015.0
# 51      45-49                  CA    male                   1232.0  2015.0
# 52      85-89                  CA  female                    300.0  2015.0
# 53      50-54                  CA    male                   1400.0  2015.0
# 54       100+                  CA    male                      1.0  2015.0
# 55      70-74                  CA    male                    650.0  2015.0
# 56      95-99                  CA  female                     42.0  2015.0
# 57       100+                  CA  female                      7.0  2015.0
# 58      90-94                  CA    male                     68.0  2015.0
# 59      50-54                  CA  female                   1391.0  2015.0
# 60        0-4                  CA    male                   1045.0  2015.0
# 61        5-9                  CA    male                   1011.0  2015.0
# 62      70-74                  CA  female                    715.0  2015.0
# 63      10-14                  CA    male                    983.0  2015.0
# 64      55-59                  CA  female                   1305.0  2015.0
# 65      45-49                  CA  female                   1217.0  2015.0
# 66      20-24                  CA  female                   1159.0  2015.0
# 67      15-19                  CA    male                   1054.0  2015.0
# 68      20-24                  CA    male                   1203.0  2015.0
# 69      65-69                  CA    male                    914.0  2015.0
# 70      40-44                  CA  female                   1169.0  2015.0
# 71      90-94                  CA  female                    153.0  2015.0
# 72      65-69                  CA  female                    973.0  2015.0
# 73      60-64                  CA    male                   1094.0  2015.0
# 74      85-89                  CA    male                    183.0  2015.0
# 75      25-29                  CA    male                   1273.0  2015.0
# 76        5-9                  CA  female                    960.0  2015.0
# 77      80-84                  CA  female                    422.0  2015.0
# 78      30-34                  CA    male                   1262.0  2015.0
# 79      10-14                  CA  female                    929.0  2015.0
# 80        0-4                  CA  female                    991.0  2015.0
# 81      35-39                  CA    male                   1189.0  2015.0
# 82      15-19                  CA  female                   1009.0  2015.0
# 83      80-84                  CA    male                    318.0  2015.0

# %% [markdown]
# #### Clean data

# %%
# Users who have NDF
train_noPurchase = train_users[train_users['country_destination']=='NDF']
noPurchase_users = set(train_noPurchase['id'])

# Users who had a booking
train_yesPurchase = train_users[train_users['country_destination']!='NDF']
yesPurchase_users = set(train_yesPurchase['id'])

# Users who had a booking outside of US
train_nonUS_purchase = train_yesPurchase[train_yesPurchase['country_destination'] != 'US']
#train_nonUS_purchase = train_nonUS_purchase[train_nonUS_purchase['country_destination'] != 'other']
train_nonUS_users = set(train_nonUS_purchase ['id'])

# If you want to include US
#train_nonUS_purchase = train_yesPurchase
#train_nonUS_users = set(train_nonUS_purchase ['id'])

# %%
# Check that US and NDF not included - there should be 9 countries + other
set(train_nonUS_purchase['country_destination'])
# Out:
# {'AU', 'CA', 'DE', 'ES', 'FR', 'GB', 'IT', 'NL', 'PT', 'other'}

# %%
len(train_nonUS_purchase)
# Out:
# 26532

# %% [markdown]
# #### Categories

# %%
#sessions_noPurchase = sessions[sessions['user_id'].isin(noPurchase_users)]
#sessions_yesPurchase = sessions[sessions['user_id'].isin(yesPurchase_users)]
#sessions_nonUS_purchase = sessions[sessions['user_id'].isin(train_nonUS_purchase)]

# %%
#final_train_users = train_users[train_users['id'].isin(sessions['user_id'])]
#final_train_users = train_users.copy()
#final_train_users = train_nonUS_purchase.copy()
#final_train_users.head()

# %%
final_train_users = train_nonUS_purchase.copy()
final_train_users = final_train_users[final_train_users['id'].isin(sessions['user_id'])]

final_train_users.head()
#sessions_nonUS_purchase = sessions[sessions['user_id'].isin(train_nonUS_purchase)]
# Out:
#                 id date_account_created  timestamp_first_active  \
# 137021  d1mm9tcy42           2014-01-01          20140101000936
# 137025  4rvqpxoh3h           2014-01-01          20140101002619
# 137029  ro2stddszp           2014-01-01          20140101005503
# 137033  ucgks2fyez           2014-01-01          20140101010900
# 137036  jrqykh9y8x           2014-01-01          20140101011919
#
#        date_first_booking     gender   age signup_method  signup_flow  \
# 137021         2014-01-04       MALE  62.0         basic            0
# 137025         2014-01-02  -unknown-   NaN         basic           25
# 137029         2014-12-04  -unknown-  19.0         basic            0
# 137033         2014-12-18  -unknown-  76.0         basic            0
# 137036         2014-04-19     FEMALE  27.0      facebook            0
#
#        language affiliate_channel affiliate_provider first_affiliate_tracked  \
# 137021       en     sem-non-brand             google                     omg
# 137025       en            direct             direct               untracked
# 137029       en         sem-brand             google               untracked
# 137033       en               seo              yahoo               untracked
# 137036       zh               seo             google                  linked
#
#        signup_app first_device_type  first_browser country_destination
# 137021        Web   Windows Desktop         Chrome               other
# 137025        iOS            iPhone      -unknown-                  GB
# 137029        Web       Mac Desktop         Safari               other
# 137033        Web              iPad  Mobile Safari               other
# 137036        Web       Mac Desktop         Chrome                  FR

# %%
categories = list(train_users.columns.values)
categories = categories[4:len(categories)-1]
categories.remove('age')
categories.remove('gender')

#categories = ['language', 'first_browser', 'signup_app', 'signup_flow']

categories
# Out:
# ['signup_method',
#  'signup_flow',
#  'language',
#  'affiliate_channel',
#  'affiliate_provider',
#  'first_affiliate_tracked',
#  'signup_app',
#  'first_device_type',
#  'first_browser']

# %%
final_train_users = final_train_users.ix[np.logical_and(final_train_users['age'] > 10, final_train_users['age'] < 80)]

# %%
final_train_users
# Out:
#                 id date_account_created  timestamp_first_active  \
# 137021  d1mm9tcy42           2014-01-01          20140101000936
# 137029  ro2stddszp           2014-01-01          20140101005503
# 137033  ucgks2fyez           2014-01-01          20140101010900
# 137036  jrqykh9y8x           2014-01-01          20140101011919
# 137076  d6r5a2l398           2014-01-01          20140101081440
# 137101  yetxlyyeja           2014-01-01          20140101180833
# 137109  ne62ok6xaf           2014-01-01          20140101184145
# 137110  ccl1h3nes7           2014-01-01          20140101184509
# 137127  ihi4gy0dyl           2014-01-01          20140101193508
# 137132  6ghzgyjfrf           2014-01-01          20140101195600
# 137142  ospxjl3y2s           2014-01-01          20140101210302
# 137173  y1rs6e7jyh           2014-01-02          20140102000545
# 137189  08kx4pqoih           2014-01-02          20140102003148
# 137190  0gwnjqum9m           2014-01-02          20140102003328
# 137191  0l461nxs9e           2014-01-02          20140102003350
# 137195  72efxf8p14           2014-01-02          20140102004315
# 137198  1tkb8vully           2014-01-02          20140102010148
# 137209  5v00ftnhc5           2014-01-02          20140102021003
# 137223  raatnx2x8u           2014-01-02          20140102025033
# 137230  862vv9ey77           2014-01-02          20140102033207
# 137243  9c9z8roxle           2014-01-02          20140102041943
# 137250  07uj7rw2h7           2014-01-02          20140102043322
# 137251  vo6xsfcocf           2014-01-02          20140102043617
# 137261  7lc3892xpc           2014-01-02          20140102050512
# 137272  hl7s8263fd           2014-01-02          20140102053844
# 137314  6efta2fnvv           2014-01-02          20140102074915
# 137322  lnvfd9aoyy           2014-01-02          20140102083910
# 137351  yitb6vxgi7           2014-01-02          20140102162836
# 137367  epj462z7bf           2014-01-02          20140102174815
# 137373  lr7zlob0ya           2014-01-02          20140102181741
# ...            ...                  ...                     ...
# 213128  f6glkfzgtc           2014-06-30          20140630134835
# 213147  ngab18k95o           2014-06-30          20140630151002
# 213157  5ule4d5nye           2014-06-30          20140630153803
# 213175  j3hzk3xj3q           2014-06-30          20140630163453
# 213185  jo2hxlxgt4           2014-06-30          20140630165352
# 213188  qgbi13z7h1           2014-06-30          20140630165643
# 213219  zluoqk9bbx           2014-06-30          20140630174425
# 213223  nh9ouf3sib           2014-06-30          20140630175829
# 213232  vr71vciv6g           2014-06-30          20140630181341
# 213238  auxgpnlw6s           2014-06-30          20140630182237
# 213249  izd3fpsd3v           2014-06-30          20140630183910
# 213255  1sjgu8lwqm           2014-06-30          20140630184708
# 213258  uj87m4s0wn           2014-06-30          20140630185107
# 213268  gj1oghtlge           2014-06-30          20140630190808
# 213277  46h0qlfnis           2014-06-30          20140630192154
# 213279  0cy56unpvk           2014-06-30          20140630192421
# 213287  1e71s11u3h           2014-06-30          20140630193752
# 213313  1wrvm4jg29           2014-06-30          20140630201214
# 213314  7s9yk4ng17           2014-06-30          20140630201221
# 213323  n97n95yljd           2014-06-30          20140630202233
# 213351  9yj2xqlard           2014-06-30          20140630211655
# 213352  iecf5zctoz           2014-06-30          20140630211706
# 213372  0co6s86hgb           2014-06-30          20140630215947
# 213388  gedoe2zmrj           2014-06-30          20140630222200
# 213390  c999p94qui           2014-06-30          20140630222253
# 213400  x17avasiuk           2014-06-30          20140630223943
# 213401  xif0n17eof           2014-06-30          20140630224049
# 213407  iu1abga5nx           2014-06-30          20140630224635
# 213415  7plqriggxp           2014-06-30          20140630230136
# 213441  omlc9iku7t           2014-06-30          20140630235151
#
#        date_first_booking     gender   age signup_method  signup_flow  \
# 137021         2014-01-04       MALE  62.0         basic            0
# 137029         2014-12-04  -unknown-  19.0         basic            0
# 137033         2014-12-18  -unknown-  76.0         basic            0
# 137036         2014-04-19     FEMALE  27.0      facebook            0
# 137076         2014-03-12       MALE  25.0      facebook           12
# 137101         2014-07-28       MALE  34.0         basic            0
# 137109         2014-01-02       MALE  35.0      facebook           12
# 137110         2014-03-24       MALE  47.0         basic           24
# 137127         2014-01-06     FEMALE  29.0         basic            0
# 137132         2014-01-09     FEMALE  45.0      facebook            0
# 137142         2014-01-01     FEMALE  34.0         basic           24
# 137173         2014-01-02       MALE  39.0         basic            0
# 137189         2014-01-02       MALE  50.0         basic            0
# 137190         2014-01-10       MALE  27.0      facebook           12
# 137191         2014-01-13     FEMALE  22.0      facebook            0
# 137195         2014-01-15     FEMALE  29.0      facebook            0
# 137198         2014-01-05       MALE  29.0      facebook            0
# 137209         2014-03-11     FEMALE  29.0         basic            0
# 137223         2014-01-02       MALE  24.0         basic            0
# 137230         2014-01-02       MALE  31.0         basic            0
# 137243         2014-05-10  -unknown-  62.0         basic            0
# 137250         2014-01-15  -unknown-  31.0         basic            0
# 137251         2014-02-04       MALE  67.0         basic            0
# 137261         2014-01-07     FEMALE  58.0         basic            0
# 137272         2014-01-03       MALE  39.0         basic           25
# 137314         2014-01-02     FEMALE  32.0         basic            0
# 137322         2014-01-06       MALE  28.0      facebook            0
# 137351         2014-01-08       MALE  33.0      facebook            0
# 137367         2014-01-14       MALE  73.0         basic            0
# 137373         2014-01-02     FEMALE  66.0         basic            0
# ...                   ...        ...   ...           ...          ...
# 213128         2014-07-11     FEMALE  22.0      facebook            0
# 213147         2014-07-01     FEMALE  24.0         basic            0
# 213157         2014-08-03       MALE  21.0      facebook            0
# 213175         2014-06-30     FEMALE  41.0         basic            0
# 213185         2014-06-30     FEMALE  28.0         basic            0
# 213188         2014-06-30       MALE  39.0         basic            0
# 213219         2014-06-30       MALE  27.0         basic            0
# 213223         2014-07-06       MALE  29.0      facebook           25
# 213232         2014-07-01  -unknown-  18.0         basic            0
# 213238         2014-07-08     FEMALE  26.0         basic            0
# 213249         2014-09-24     FEMALE  29.0      facebook            0
# 213255         2014-07-01       MALE  45.0      facebook            0
# 213258         2014-08-13     FEMALE  28.0      facebook            0
# 213268         2014-06-30       MALE  22.0      facebook            0
# 213277         2014-07-14  -unknown-  63.0         basic            0
# 213279         2014-06-30     FEMALE  22.0         basic            0
# 213287         2014-11-05       MALE  36.0      facebook            0
# 213313         2014-06-30       MALE  50.0      facebook            0
# 213314         2014-07-05     FEMALE  32.0         basic            0
# 213323         2014-10-01       MALE  28.0      facebook            0
# 213351         2014-07-01       MALE  34.0      facebook            0
# 213352         2014-07-01     FEMALE  28.0         basic            0
# 213372         2015-04-13       MALE  41.0      facebook            0
# 213388         2015-03-01     FEMALE  30.0         basic            0
# 213390         2014-07-08     FEMALE  30.0         basic            0
# 213400         2014-08-04       MALE  53.0         basic           23
# 213401         2014-07-15  -unknown-  45.0         basic            0
# 213407         2014-06-30     FEMALE  21.0      facebook            0
# 213415         2014-06-30  -unknown-  55.0         basic            0
# 213441         2014-08-13     FEMALE  34.0         basic            0
#
#        language affiliate_channel affiliate_provider first_affiliate_tracked  \
# 137021       en     sem-non-brand             google                     omg
# 137029       en         sem-brand             google               untracked
# 137033       en               seo              yahoo               untracked
# 137036       zh               seo             google                  linked
# 137076       en               api              other               untracked
# 137101       en            direct             direct               untracked
# 137109       en               api              other               untracked
# 137110       en            direct             direct                  linked
# 137127       en            direct             direct               untracked
# 137132       en            direct             direct                  linked
# 137142       en            direct             direct               untracked
# 137173       en            direct             direct               untracked
# 137189       en            direct             direct               untracked
# 137190       en               api              other               untracked
# 137191       en         sem-brand             google                     omg
# 137195       en               seo             google                  linked
# 137198       en            direct             direct               untracked
# 137209       en         sem-brand             google                  linked
# 137223       en            direct             direct               untracked
# 137230       en            direct             direct                  linked
# 137243       en            direct             direct               untracked
# 137250       en            direct             direct                  linked
# 137251       en         sem-brand             google                     omg
# 137261       en     sem-non-brand             google                     omg
# 137272       en            direct             direct               untracked
# 137314       en         sem-brand             google                  linked
# 137322       ko            direct             direct               untracked
# 137351       en            direct             direct               untracked
# 137367       en            direct             direct                  linked
# 137373       en         sem-brand             google               untracked
# ...         ...               ...                ...                     ...
# 213128       en         sem-brand             google                  linked
# 213147       en            direct             direct               untracked
# 213157       en            direct             direct                  linked
# 213175       en             other              other                  linked
# 213185       en               seo             google                  linked
# 213188       en            direct             direct                     omg
# 213219       en            direct             direct               untracked
# 213223       en            direct             direct               untracked
# 213232       en            direct             direct               untracked
# 213238       en         sem-brand             google                     omg
# 213249       en            direct             direct                  linked
# 213255       en            direct             direct               untracked
# 213258       en         sem-brand             google                     omg
# 213268       en               seo             google               untracked
# 213277       en         sem-brand               bing                     omg
# 213279       en            direct             direct                  linked
# 213287       en            direct             direct               untracked
# 213313       en            direct             direct                  linked
# 213314       en         sem-brand             google                     omg
# 213323       en            direct             direct               untracked
# 213351       en         sem-brand             google                  linked
# 213352       en            direct             direct                  linked
# 213372       en             other          padmapper                     omg
# 213388       en            direct             direct               untracked
# 213390       en            direct             direct                  linked
# 213400       en            direct             direct               untracked
# 213401       en         sem-brand             google                     omg
# 213407       en         sem-brand             google                     omg
# 213415       en         sem-brand             google                     omg
# 213441       en            direct             direct                  linked
#
#        signup_app first_device_type  first_browser country_destination
# 137021        Web   Windows Desktop         Chrome               other
# 137029        Web       Mac Desktop         Safari               other
# 137033        Web              iPad  Mobile Safari               other
# 137036        Web       Mac Desktop         Chrome                  FR
# 137076    Android     Other/Unknown      -unknown-               other
# 137101        Web   Windows Desktop             IE               other
# 137109        iOS            iPhone  Mobile Safari               other
# 137110      Moweb       Mac Desktop         Chrome                  GB
# 137127        Web   Windows Desktop         Chrome               other
# 137132        Web       Mac Desktop         Safari                  IT
# 137142      Moweb     Android Phone  Chrome Mobile                  IT
# 137173        Web       Mac Desktop         Chrome               other
# 137189        Web              iPad  Mobile Safari               other
# 137190        iOS            iPhone  Mobile Safari                  AU
# 137191        Web       Mac Desktop         Chrome                  GB
# 137195        Web       Mac Desktop         Chrome               other
# 137198        Web       Mac Desktop         Safari                  AU
# 137209        Web              iPad  Mobile Safari                  CA
# 137223        Web       Mac Desktop         Chrome                  IT
# 137230        Web       Mac Desktop         Chrome               other
# 137243        Web   Windows Desktop   AOL Explorer                  IT
# 137250        Web   Windows Desktop         Chrome                  FR
# 137251        Web       Mac Desktop         Safari                  FR
# 137261        Web   Windows Desktop         Chrome               other
# 137272        iOS            iPhone  Mobile Safari               other
# 137314        Web   Windows Desktop        Firefox               other
# 137322        Web   Windows Desktop             IE                  FR
# 137351        Web   Windows Desktop             IE               other
# 137367        Web   Windows Desktop        Firefox               other
# 137373        Web   Windows Desktop             IE                  FR
# ...           ...               ...            ...                 ...
# 213128        Web   Windows Desktop         Chrome                  NL
# 213147        Web   Windows Desktop             IE               other
# 213157        Web       Mac Desktop         Safari                  IT
# 213175        Web            iPhone  Mobile Safari               other
# 213185        Web   Windows Desktop         Chrome               other
# 213188        Web   Windows Desktop         Chrome                  FR
# 213219        Web   Windows Desktop        Firefox                  IT
# 213223        iOS            iPhone      -unknown-                  IT
# 213232        Web   Windows Desktop             IE               other
# 213238        Web       Mac Desktop         Chrome               other
# 213249        Web   Windows Desktop         Chrome                  CA
# 213255        Web   Windows Desktop        Firefox                  CA
# 213258        Web   Windows Desktop         Chrome               other
# 213268        Web   Windows Desktop         Chrome                  GB
# 213277        Web   Windows Desktop             IE                  DE
# 213279        Web       Mac Desktop         Chrome               other
# 213287        Web       Mac Desktop         Chrome                  GB
# 213313        Web            iPhone  Mobile Safari               other
# 213314        Web   Windows Desktop        Firefox               other
# 213323        Web   Windows Desktop         Chrome                  FR
# 213351        Web       Mac Desktop         Chrome                  NL
# 213352        Web   Windows Desktop         Chrome                  FR
# 213372        Web       Mac Desktop         Safari                  GB
# 213388        Web       Mac Desktop         Chrome                  IT
# 213390        Web       Mac Desktop         Chrome                  AU
# 213400    Android     Other/Unknown      -unknown-               other
# 213401        Web       Mac Desktop        Firefox                  FR
# 213407        Web              iPad  Mobile Safari                  ES
# 213415        Web    Android Tablet             IE                  FR
# 213441        Web       Mac Desktop         Chrome                  ES
#
# [6258 rows x 16 columns]

# %%
def category_bool(catName, catItem):
    user_app = final_train_users[final_train_users[catName] == catItem]
    performed = final_train_users['id'].isin(user_app['id'])
    colname = str(catName) + '_' + str(catItem)
    final_train_users[colname] = performed

for category in categories:
    items = final_train_users[category].dropna().drop_duplicates()
    for item in items:
        category_bool(category, item)

#print(len(final_train_users[0]))
#final_train_users[final_train_users['signup_app_iOS']==True]
final_train_users.head()
# Out:
#                 id date_account_created  timestamp_first_active  \
# 137021  d1mm9tcy42           2014-01-01          20140101000936
# 137029  ro2stddszp           2014-01-01          20140101005503
# 137033  ucgks2fyez           2014-01-01          20140101010900
# 137036  jrqykh9y8x           2014-01-01          20140101011919
# 137076  d6r5a2l398           2014-01-01          20140101081440
#
#        date_first_booking     gender   age signup_method  signup_flow  \
# 137021         2014-01-04       MALE  62.0         basic            0
# 137029         2014-12-04  -unknown-  19.0         basic            0
# 137033         2014-12-18  -unknown-  76.0         basic            0
# 137036         2014-04-19     FEMALE  27.0      facebook            0
# 137076         2014-03-12       MALE  25.0      facebook           12
#
#        language affiliate_channel          ...            \
# 137021       en     sem-non-brand          ...
# 137029       en         sem-brand          ...
# 137033       en               seo          ...
# 137036       zh               seo          ...
# 137076       en               api          ...
#
#        first_browser_SeaMonkey first_browser_Iron first_browser_Opera  \
# 137021                   False              False               False
# 137029                   False              False               False
# 137033                   False              False               False
# 137036                   False              False               False
# 137076                   False              False               False
#
#        first_browser_Silk first_browser_Chromium first_browser_IceWeasel  \
# 137021              False                  False                   False
# 137029              False                  False                   False
# 137033              False                  False                   False
# 137036              False                  False                   False
# 137076              False                  False                   False
#
#        first_browser_SiteKiosk first_browser_Maxthon first_browser_CoolNovo  \
# 137021                   False                 False                  False
# 137029                   False                 False                  False
# 137033                   False                 False                  False
# 137036                   False                 False                  False
# 137076                   False                 False                  False
#
#        first_browser_RockMelt
# 137021                  False
# 137029                  False
# 137033                  False
# 137036                  False
# 137076                  False
#
# [5 rows x 100 columns]

# %%
genders = final_train_users['gender'].dropna().drop_duplicates()
for item in items:
    if (item != '-unknown-'):
        category_bool('gender', item)

#print(len(final_train_users[0]))
#final_train_users[final_train_users['signup_app_iOS']==True]
final_train_users.head()
# Out:
#                 id date_account_created  timestamp_first_active  \
# 137021  d1mm9tcy42           2014-01-01          20140101000936
# 137029  ro2stddszp           2014-01-01          20140101005503
# 137033  ucgks2fyez           2014-01-01          20140101010900
# 137036  jrqykh9y8x           2014-01-01          20140101011919
# 137076  d6r5a2l398           2014-01-01          20140101081440
#
#        date_first_booking     gender   age signup_method  signup_flow  \
# 137021         2014-01-04       MALE  62.0         basic            0
# 137029         2014-12-04  -unknown-  19.0         basic            0
# 137033         2014-12-18  -unknown-  76.0         basic            0
# 137036         2014-04-19     FEMALE  27.0      facebook            0
# 137076         2014-03-12       MALE  25.0      facebook           12
#
#        language affiliate_channel       ...       gender_SeaMonkey  \
# 137021       en     sem-non-brand       ...                  False
# 137029       en         sem-brand       ...                  False
# 137033       en               seo       ...                  False
# 137036       zh               seo       ...                  False
# 137076       en               api       ...                  False
#
#        gender_Iron gender_Opera gender_Silk gender_Chromium gender_IceWeasel  \
# 137021       False        False       False           False            False
# 137029       False        False       False           False            False
# 137033       False        False       False           False            False
# 137036       False        False       False           False            False
# 137076       False        False       False           False            False
#
#        gender_SiteKiosk gender_Maxthon gender_CoolNovo gender_RockMelt
# 137021            False          False           False           False
# 137029            False          False           False           False
# 137033            False          False           False           False
# 137036            False          False           False           False
# 137076            False          False           False           False
#
# [5 rows x 120 columns]

# %%
## Append Seasons

from datetime import datetime, date
from sklearn.preprocessing import OneHotEncoder

#### Get the Date
Y = 2000 # dummy leap year to allow input X-02-29 (leap day)
seasons = [(0, (date(Y,  1,  1),  date(Y,  3, 20))),  #'winter'
           (1, (date(Y,  3, 21),  date(Y,  6, 20))),  #'spring'
           (2, (date(Y,  6, 21),  date(Y,  9, 22))),  #'summer'
           (3, (date(Y,  9, 23),  date(Y, 12, 20))),  #'autumn'
           (0, (date(Y, 12, 21),  date(Y, 12, 31)))]  #'winter'

def get_season(now):
    date_format = "%Y-%m-%d"
    d1 = now
    now = datetime.strptime(d1, date_format)
    
    if isinstance(now, datetime):
        now = now.date()
    now = now.replace(year=Y)
    return next(season for season, (start, end) in seasons
                if start <= now <= end)

enc = OneHotEncoder()
a = np.array(final_train_users['date_account_created'].apply(get_season))
a = a[:,np.newaxis]
dateFeat = enc.fit_transform(a)
dateFeat = dateFeat.toarray()

for i in range(len(dateFeat[0])):
    category = 'season_' + str(i)
    final_train_users[category] = dateFeat[:,i]

# %%
## Append Month

def get_month(now):
    return now[5:7]

a = np.array(final_train_users['date_account_created'].apply(get_month))
a = a[:,np.newaxis]
dateFeat = enc.fit_transform(a)
dateFeat = dateFeat.toarray()

for i in range(len(dateFeat[0])):
    category = 'month_' + str(i)
    final_train_users[category] = dateFeat[:,i]

# %%
## Append Year

def get_year(now):
    return now[:4]

a = np.array(final_train_users['date_account_created'].apply(get_year))
a = a[:,np.newaxis]
dateFeat = enc.fit_transform(a)
dateFeat = dateFeat.toarray()

for i in range(len(dateFeat[0])):
    category = 'year_' + str(i)
    final_train_users[category] = dateFeat[:,i]

# %%
## Append TFA - DAC

import datetime

final_train_users['tfa-dac'] = final_train_users.apply(lambda x: (datetime.datetime.strptime(x['date_account_created'], '%Y-%m-%d') \
                     - datetime.datetime.strptime(str(x['timestamp_first_active'])[:-6], '%Y%m%d')).total_seconds()\
          /(60*60*24.0) \
          ,axis=1)

# %%
def action_bool(action):
    user_action = sessions[sessions['action'] == action]
    performed = final_train_users['id'].isin(user_action['user_id'])
    colname = 'b_' + action
    final_train_users[colname] = performed

#all actions
actions = sessions['action'].dropna().drop_duplicates()
for action in actions:
    action_bool(action)
    
final_train_users.head()

# %%
final_train_users.columns.values
# Out:
# array(['id', 'date_account_created', 'timestamp_first_active',
#        'date_first_booking', 'gender', 'age', 'signup_method',
#        'signup_flow', 'language', 'affiliate_channel',
#        'affiliate_provider', 'first_affiliate_tracked', 'signup_app',
#        'first_device_type', 'first_browser', 'country_destination',
#        'language_en', 'language_zh', 'language_ko', 'language_nl',
#        'language_de', 'language_pl', 'language_fr', 'language_es',
#        'language_it', 'language_el', 'language_ru', 'language_ja',
#        'language_pt', 'language_sv', 'language_cs', 'language_fi',
#        'language_th', 'language_tr', 'first_browser_Chrome',
#        'first_browser_-unknown-', 'first_browser_Safari',
#        'first_browser_Mobile Safari', 'first_browser_Firefox',
#        'first_browser_IE', 'first_browser_Chrome Mobile',
#        'first_browser_AOL Explorer', 'first_browser_Apple Mail',
#        'first_browser_Android Browser', 'first_browser_wOSBrowser',
#        'first_browser_Silk', 'first_browser_Sogou Explorer',
#        'first_browser_Chromium', 'first_browser_SeaMonkey',
#        'first_browser_Iron', 'first_browser_Opera',
#        'first_browser_Maxthon', 'first_browser_Googlebot',
#        'first_browser_IceWeasel', 'first_browser_SiteKiosk',
#        'first_browser_CoolNovo', 'first_browser_RockMelt',
#        'signup_app_Web', 'signup_app_iOS', 'signup_app_Android',
#        'signup_app_Moweb', 'signup_flow_0', 'signup_flow_25',
#        'signup_flow_12', 'signup_flow_24', 'signup_flow_23',
#        'signup_flow_8', 'season_0', 'season_1', 'season_2', 'month_0',
#        'month_1', 'month_2', 'month_3', 'month_4', 'month_5', 'b_lookup',
#        'b_search_results', 'b_personalize', 'b_index',
#        'b_similar_listings', 'b_ajax_refresh_subtotal', 'b_show',
#        'b_header_userpic', 'b_ask_question',
#        'b_other_hosting_reviews_first', 'b_hosting_social_proof',
#        'b_decision_tree', 'b_recent_reservations', 'b_faq_experiment_ids',
#        'b_multi', 'b_active', 'b_dashboard', 'b_create', 'b_confirm_email',
#        'b_show_personalize', 'b_verify', 'b_pending', 'b_requested',
#        'b_concierge', 'b_faq', 'b_clear_reservation',
#        'b_cancellation_policies', 'b_track_page_view', 'b_update', 'b_my',
#        'b_campaigns', 'b_notifications', 'b_listings',
#        'b_unavailabilities', 'b_ajax_lwlb_contact', 'b_ajax_check_dates',
#        'b_qt2', 'b_request_new_confirm_email',
#        'b_ajax_photo_widget_form_iframe', 'b_facebook_auto_login',
#        'b_identity', 'b_qt_reply_v2', 'b_travel_plans_current',
#        'b_complete_status', 'b_populate_from_facebook', 'b_kba_update',
#        'b_kba', 'b_login', 'b_authenticate', 'b_calendar_tab_inner2',
#        'b_other_hosting_reviews', 'b_social_connections', 'b_relationship',
#        'b_15', 'b_collections', 'b_12', 'b_jumio_redirect',
#        'b_jumio_token', 'b_login_modal', 'b_domains',
#        'b_toggle_archived_thread', 'b_search', 'b_edit_verification',
#        'b_edit', 'b_ajax_ldp', 'b_connect', 'b_account', 'b_delete',
#        'b_phone_number_widget', 'b_callback', 'b_signup_modal', 'b_10',
#        'b_open_graph_setting', 'b_reviews', 'b_signup_login',
#        'b_payment_instruments', 'b_payment_methods', 'b_pay', 'b_unread',
#        'b_at_checkpoint', 'b_push_notification_callback', 'b_faq_category',
#        'b_localization_settings', 'b_update_notifications',
#        'b_manage_listing', 'b_set_user', 'b_references',
#        'b_languages_multiselect', 'b_salute', 'b_rentals', 'b_currencies',
#        'b_new', 'b_position', 'b_populate_help_dropdown', 'b_popular',
#        'b_popular_listing', 'b_listing', 'b_available', 'b_glob',
#        'b_this_hosting_reviews', 'b_widget', 'b_complete', 'b_profile_pic',
#        'b_signature', 'b_apply_reservation', 'b_ajax_statsd', 'b_travel',
#        'b_tos_confirm', 'b_uptodate', 'b_ajax_payout_options_by_country',
#        'b_payout_preferences', 'b_payout_update', 'b_ajax_payout_edit',
#        'b_pending_tickets', 'b_issue', 'b_contact_new', 'b_itinerary',
#        'b_receipt', 'b_update_hide_from_search_engines', 'b_settings',
#        'b_privacy', 'b_reviews_new', 'b_add_guests', 'b_ajax_image_upload',
#        'b_qt_with', 'b_webcam_upload', 'b_friends',
#        'b_ajax_google_translate_description', 'b_trust', 'b_guarantee',
#        'b_supported', 'b_countries', 'b_status', 'b_upload', 'b_authorize',
#        'b_rate', 'b_remove_dashboard_alert', 'b_ajax_get_results',
#        'b_recommend', 'b_change_currency',
#        'b_transaction_history_paginated', 'b_transaction_history',
#        'b_set_password', 'b_cancel', 'b_phone_verification_modal',
#        'b_submit_contact', 'b_detect_fb_session', 'b_tell_a_friend',
#        'b_change', 'b_clickthrough', 'b_multi_message_attributes',
#        'b_update_friends_display', 'b_my_listings',
#        'b_email_itinerary_colorbox', 'b_mobile_landing_page',
#        'b_create_ach', 'b_country_options', 'b_11', 'b_host_2013',
#        'b_terms', 'b_multi_message', 'b_ajax_send_message',
#        'b_airbnb_picks', 'b_friends_new', 'b_reputation',
#        'b_complete_redirect', 'b_toggle_starred_thread', 'b_email_share',
#        'b_email_wishlist', 'b_destroy', 'b_add_note', 'b_overview',
#        'b_requirements', 'b_update_reservation_requirements',
#        'b_image_order', 'b_review_page', 'b_ajax_worth', 'b_place_worth',
#        'b_google_importer', 'b_change_availability', 'b_hospitality',
#        'b_change_password', 'b_feed', 'b_host_summary',
#        'b_ajax_price_and_availability', 'b_jumio',
#        'b_guest_booked_elsewhere', 'b_about_us', 'b_founders',
#        'b_travel_plans_previous', 'b_why_host', 'b_hospitality_standards',
#        'b_social', 'b_recommendations', 'b_update_cached', 'b_become_user',
#        'b_departments', 'b_department', 'b_office_location',
#        'b_photography', 'b_preapproval', 'b_maybe_information',
#        'b_toggle_availability', 'b_payoneer_account_redirect',
#        'b_forgot_password', 'b_new_host', 'b_payoneer_signup_complete',
#        'b_ajax_google_translate', 'b_onenight', 'b_approve', 'b_nyan',
#        'b_booking', 'b_payout_delete', 'b_change_default_payout',
#        'b_envoy_bank_details_redirect', 'b_respond',
#        'b_request_photography', 'b_zendesk_login_jwt',
#        'b_ajax_photo_widget', 'b_message', 'b_southern-europe', 'b_life',
#        'b_press_release', 'b_media_resources', 'b_press_news',
#        'b_referrer_status', 'b_create_multiple', 'b_load_more',
#        'b_create_paypal', 'b_locale_from_host', 'b_terms_and_conditions',
#        'b_invalid_action', 'b_photography_update', 'b_badge', 'b_apply',
#        'b_redirect', 'b_pricing', 'b_apply_code', 'b_slideshow',
#        'b_locations', 'b_ajax_google_translate_reviews', 'b_new_session',
#        'b_has_profile_pic', 'b_sublets', 'b_wishlists', 'b_reservation',
#        'b_localized', 'b_home_safety_landing', 'b_click', 'b_how_it_works',
#        'b_ajax_get_referrals_amt', 'b_phone_verification', 'b_satisfy',
#        'b_city_count', 'b_recommendation_page', 'b_press_content',
#        'b_guest_billing_receipt', 'b_ajax_payout_split_edit',
#        'b_print_confirmation', 'b_envoy_form',
#        'b_ajax_special_offer_dates_available',
#        'b_ajax_referral_banner_experiment_type', 'b_patch', 'b_questions',
#        'b_home_safety_terms', 'b_track_activity', 'b_check', 'b_sldf',
#        'b_recommended_listings', 'b_mobile_oauth_callback', 'b_show_code',
#        'b_signed_out_modal', 'b_plaxo_cb', 'b_views', 'b_friend_listing',
#        'b_ajax_referral_banner_type', 'b_deactivate', 'b_sync',
#        'b_social-media', 'b_united-states', 'b_email_by_key',
#        'b_disaster_action', 'b_views_campaign', 'b_update_message',
#        'b_spoken_languages', 'b_use_mobile_site', 'b_deauthorize',
#        'b_special_offer', 'b_top_destinations', 'b_create_airbnb',
#        'b_handle_vanity_url', 'b_impressions', 'b_message_to_host_focus',
#        'b_cancellation_policy_click', 'b_message_to_host_change',
#        'b_agree_terms_check', 'b_read_policy_click',
#        'b_phone_verification_success',
#        'b_phone_verification_number_sucessfully_submitted',
#        'b_phone_verification_number_submitted_for_sms',
#        'b_phone_verification_phone_number_removed', 'b_endpoint_error',
#        'b_p4_refund_policy_terms', 'b_apply_coupon_error_type',
#        'b_apply_coupon_error', 'b_apply_coupon_click',
#        'b_coupon_field_focus', 'b_coupon_code_click',
#        'b_agree_terms_uncheck', 'b_p4_terms',
#        'b_phone_verification_call_taking_too_long',
#        'b_phone_verification_number_submitted_for_call',
#        'b_phone_verification_error', 'b_apply_coupon_click_success',
#        'b_set_default', 'b_update_country_of_residence',
#        'b_open_hard_fallback_modal', 'b_tos_2014',
#        'b_views_campaign_rules', 'b_weibo_signup_referral_finish',
#        'b_signup_weibo_referral', 'b_similar_listings_v2',
#        'b_confirmation', 'b_signup_weibo', 'b_acculynk_load_pin_pad',
#        'b_acculynk_bin_check_success', 'b_acculynk_session_obtained',
#        'b_acculynk_pin_pad_inactive', 'b_reactivate', 'b_airbrb',
#        'b_desks', 'b_sandy', 'b_unsubscribe', 'b_host_cancel',
#        'b_acculynk_bin_check_failed', 'b_acculynk_pin_pad_error',
#        'b_custom_recommended_destinations', 'b_this_hosting_reviews_3000',
#        'b_reset_calendar', 'b_events', 'b_business_travel',
#        'b_add_guest_colorbox', 'b_hard_fallback_submit',
#        'b_add_business_address_colorbox', 'b_my_reservations', 'b_report',
#        'b_book', 'b_revert_to_admin', 'b_acculynk_pin_pad_success',
#        'b_south-america', 'b_braintree_client_token', 'b_view', 'b_stpcv',
#        'b_set_minimum_payout_amount', 'b_support_phone_numbers',
#        'b_refund_guest_cancellation', 'b_accept_decline', 'b_deactivated',
#        'b_rest-of-world', 'gender_MALE', 'gender_-unknown-',
#        'gender_FEMALE', 'gender_OTHER', 'signup_method_basic',
#        'signup_method_facebook', 'signup_method_google',
#        'affiliate_channel_sem-non-brand', 'affiliate_channel_sem-brand',
#        'affiliate_channel_seo', 'affiliate_channel_api',
#        'affiliate_channel_direct', 'affiliate_channel_content',
#        'affiliate_channel_other', 'affiliate_channel_remarketing',
#        'affiliate_provider_google', 'affiliate_provider_yahoo',
#        'affiliate_provider_other', 'affiliate_provider_direct',
#        'affiliate_provider_bing', 'affiliate_provider_facebook',
#        'affiliate_provider_facebook-open-graph',
#        'affiliate_provider_naver', 'affiliate_provider_padmapper',
#        'affiliate_provider_vast', 'affiliate_provider_baidu',
#        'affiliate_provider_email-marketing', 'first_affiliate_tracked_omg',
#        'first_affiliate_tracked_untracked',
#        'first_affiliate_tracked_linked',
#        'first_affiliate_tracked_tracked-other',
#        'first_affiliate_tracked_product',
#        'first_affiliate_tracked_marketing',
#        'first_device_type_Windows Desktop',
#        'first_device_type_Mac Desktop', 'first_device_type_iPad',
#        'first_device_type_Other/Unknown', 'first_device_type_iPhone',
#        'first_device_type_Android Phone',
#        'first_device_type_Desktop (Other)',
#        'first_device_type_Android Tablet', 'tfa-dac'], dtype=object)

# %%
## Shuffle Training Set

trainsh = shuffle(final_train_users,random_state = 42).reset_index()

trainsh = pd.concat([ trainsh[list(final_train_users)[15:]], trainsh['age'] ], axis=1)
#trainsh = trainsh[list(final_train_users)[15:]]

trainsh = trainsh.dropna()
trainshX = trainsh.drop(['country_destination'], axis=1)
trainshY = trainsh['country_destination']
cutoff = int(round(len(trainsh) * 0.8))
print "cutoff: " + str(cutoff)
# Out:
# cutoff: 5006

# %%
## Convert country label y to integer format

countryList = sorted(list(set(trainsh['country_destination'])))
print(countryList)
n_classes = len(countryList)
d = defaultdict(list)
for c in countryList:
    d[c] = countryList.index(c)

def getLabel(c):
    return d[c]
    
#from sklearn.preprocessing import label_binarize
#newtrainshY = label_binarize(trainshY, classes=countryList)

newtrainshY = trainshY.apply(getLabel)
# Out:
# ['AU', 'CA', 'DE', 'ES', 'FR', 'GB', 'IT', 'NL', 'PT', 'other']

# %%
##Split into Train and Validation

X = np.array(trainshX)
#y = np.array(trainshY != 'NDF')
y = newtrainshY

Xtrain = np.array(X[:cutoff], dtype=int)
ytrain = np.array(y[:cutoff], dtype=int)

Xval = np.array(X[cutoff:], dtype=int)
yval = np.array(y[cutoff:], dtype=int)
#Xtrain = Xtrain[:, np.newaxis]
#Xval = Xval[:, np.newaxis]

# %% [markdown]
# #### Predictor

# %%
print(np.shape(Xtrain))
print(np.shape(ytrain))
print(np.shape(Xval))
print(np.shape(yval))
# Out:
# (5006, 462)
# (5006,)
# (1252, 462)
# (1252,)

# %%
from sklearn.model_selection import KFold, RandomizedSearchCV
from sklearn.metrics import accuracy_score, f1_score, make_scorer,  roc_curve, auc
from scipy.stats import randint as sp_randint

from sklearn.svm import SVC
from sklearn.multiclass import OneVsRestClassifier

## Random Forest
#from sklearn.ensemble import RandomForestClassifier
#params = {'n_estimators': 100, 'max_depth': 9, 'verbose':1} 
#clf = RandomForestClassifier(**params)

## Gradient Boosting (sklearn)
#from sklearn.ensemble import GradientBoostingClassifier
#params = {'n_estimators': 30, 'max_depth': 10, 'learning_rate': 0.1, 'loss':'deviance', 'verbose':1} 
#clf = GradientBoostingClassifier(**params)

## One vs Rest Multiclass with SVC
from sklearn.multiclass import OneVsRestClassifier
#clf =  OneVsRestClassifier(LinearSVC(random_state=0, probability=True, verbose=True))

#params = {'n_estimators': 3, 'max_depth': 10, 'learning_rate': 0.1,  'criterion':'mae', 'verbose':1} 
#clf =  OneVsRestClassifier(GradientBoostingClassifier(**params))


#from sklearn.multiclass import OneVsRestClassifier
#params = {'n_estimators': 100, 'learning_rate': 0.1, 'verbose':1} 
#clf =  OneVsOneClassifier(SVC(verbose=1))

from sklearn.multiclass import OneVsRestClassifier
params = {'n_estimators': 100, 'learning_rate': 0.1, 'verbose':1, 'random_state':42} 
#clf =  OneVsOneClassifier(GradientBoostingClassifier(**params))
clf =  OneVsRestClassifier(GradientBoostingClassifier(**params))



#from sklearn.ensemble import RandomForestClassifier
#params = {'n_estimators' : 30, 'max_depth':10, 'verbose':1}
#clf =  OneVsRestClassifier(RandomForestClassifier(**params))

##  Adaboost
#from sklearn.ensemble import AdaBoostClassifier
#from sklearn.tree import DecisionTreeClassifier
#clf = AdaBoostClassifier(
#    DecisionTreeClassifier(max_depth=9),
#    n_estimators=600,
#    learning_rate=0.1)

# %%
clf.fit(Xtrain, ytrain)
#probs = clf.predict_proba(Xval)
# Out:
#       Iter       Train Loss   Remaining Time
#          1           0.2001            2.04s
#          2           0.1958            2.81s
#          3           0.1921            3.06s
#          4           0.1905            3.43s
#          5           0.1871            3.73s
#          6           0.1851            3.80s
#          7           0.1829            3.79s
#          8           0.1821            3.79s
#          9           0.1797            3.93s
#         10           0.1783            3.99s
#         20           0.1666            3.37s
#         30           0.1564            2.86s
#         40           0.1504            2.41s
#         50           0.1428            1.98s
#         60           0.1371            1.53s
#         70           0.1322            1.14s
#         80           0.1301            0.74s
#         90           0.1267            0.37s
#        100           0.1232            0.00s
#       Iter       Train Loss   Remaining Time
#          1           0.4215            1.94s
#          2           0.4160            2.91s
#          3           0.4154            2.53s
#          4           0.4141            2.44s
#          5           0.4127            2.48s
#          6           0.4117            2.45s
#          7           0.4085            2.72s
#          8           0.4070            2.63s
#          9           0.4043            2.62s
#         10           0.4033            2.55s
#         20           0.3887            2.56s
#         30           0.3786            2.19s
#         40           0.3718            1.87s
#         50           0.3643            1.61s
#         60           0.3569            1.30s
#         70           0.3483            0.97s
#         80           0.3414            0.65s
#         90           0.3357            0.33s
#        100           0.3313            0.00s
#       Iter       Train Loss   Remaining Time
#          1           0.2762            2.01s
#          2           0.2740            2.20s
#          3           0.2711            2.62s
#          4           0.2702            2.48s
#          5           0.2691            2.42s
#          6           0.2679            2.59s
#          7           0.2657            2.80s
#          8           0.2623            2.97s
#          9           0.2619            2.82s
#         10           0.2614            2.70s
#         20           0.2507            2.71s
#         30           0.2413            2.34s
#         40           0.2322            2.05s
#         50           0.2266            1.69s
#         60           0.2203            1.33s
#         70           0.2171            0.99s
#         80           0.2110            0.65s
#         90           0.2080            0.32s
#        100           0.2024            0.00s
#       Iter       Train Loss   Remaining Time
#          1           0.5751            3.54s
#          2           0.5725            3.56s
#          3           0.5702            3.56s
#          4           0.5684            3.57s
#          5           0.5667            3.51s
#          6           0.5654            3.45s
#          7           0.5641            3.23s
#          8           0.5618            3.14s
#          9           0.5597            3.08s
#         10           0.5590            2.98s
#         20           0.5458            2.72s
#         30           0.5376            2.30s
#         40           0.5292            1.97s
#         50           0.5207            1.66s
#         60           0.5140            1.34s
#         70           0.5079            0.97s
#         80           0.5032            0.64s
#         90           0.4973            0.32s
#        100           0.4942            0.00s
#       Iter       Train Loss   Remaining Time
#          1           0.9015            5.05s
#          2           0.8985            4.35s
#          3           0.8966            3.95s
#          4           0.8942            3.99s
#          5           0.8922            3.95s
#          6           0.8898            4.10s
#          7           0.8873            4.17s
#          8           0.8855            4.12s
#          9           0.8835            4.07s
#         10           0.8817            4.12s
#         20           0.8683            3.34s
#         30           0.8567            2.79s
#         40           0.8486            2.29s
#         50           0.8409            1.84s
#         60           0.8353            1.43s
#         70           0.8273            1.06s
#         80           0.8215            0.69s
#         90           0.8172            0.34s
#        100           0.8113            0.00s
#       Iter       Train Loss   Remaining Time
#          1           0.5659            5.04s
#          2           0.5624            4.80s
#          3           0.5599            4.85s
#          4           0.5576            4.82s
#          5           0.5554            4.63s
#          6           0.5536            4.60s
#          7           0.5515            4.58s
#          8           0.5501            4.36s
#          9           0.5489            4.27s
#         10           0.5462            4.10s
#         20           0.5305            3.32s
#         30           0.5186            2.74s
#         40           0.5094            2.23s
#         50           0.5018            1.83s
#         60           0.4942            1.45s
#         70           0.4881            1.08s
#         80           0.4836            0.71s
#         90           0.4779            0.35s
#        100           0.4718            0.00s
#       Iter       Train Loss   Remaining Time
#          1           0.6609            2.96s
#          2           0.6589            2.79s
#          3           0.6571            2.93s
#          4           0.6560            2.79s
#          5           0.6532            3.22s
#          6           0.6523            2.95s
#          7           0.6493            3.07s
#          8           0.6474            3.13s
#          9           0.6461            3.07s
#         10           0.6457            2.90s
#         20           0.6357            2.54s
#         30           0.6262            2.24s
#         40           0.6168            1.88s
#         50           0.6109            1.55s
#         60           0.6045            1.26s
#         70           0.5985            0.95s
#         80           0.5922            0.63s
#         90           0.5876            0.32s
#        100           0.5848            0.00s
#       Iter       Train Loss   Remaining Time
#          1           0.2692            2.47s
#          2           0.2647            2.69s
#          3           0.2628            3.23s
#          4           0.2612            3.16s
#          5           0.2603            3.32s
#          6           0.2579            3.23s
#          7           0.2550            3.30s
#          8           0.2520            3.31s
#          9           0.2492            3.47s
#         10           0.2482            3.46s
#         20           0.2302            3.32s
#         30           0.2227            2.95s
#         40           0.2174            2.52s
#         50           0.2091            2.10s
#         60           0.2014            1.65s
#         70           0.1961            1.20s
#         80           0.1940            0.77s
#         90           0.1899            0.38s
#        100           0.1864            0.00s
#       Iter       Train Loss   Remaining Time
#          1           0.0830            2.65s
#          2           0.0788            2.46s
#          3           0.0753            2.49s
#          4           0.0725            2.62s
#          5           0.0676            2.90s
#          6           0.0661            2.80s
#          7           0.0627            2.84s
#          8           0.0598            2.76s
#          9           0.0574            2.70s
#         10           0.0558            2.64s
#         20           0.0461            2.59s
#         30           0.0431            2.42s
#         40           0.0396            2.08s
#         50           0.0378            1.75s
#         60           0.0342            1.40s
#         70           0.0334            1.02s
#         80           0.0299            0.70s
#         90           0.0277            0.37s
#        100           0.0242            0.00s
#       Iter       Train Loss   Remaining Time
#          1           1.3532            5.87s
#          2           1.3485            5.81s
#          3           1.3450            5.19s
#          4           1.3414            5.33s
#          5           1.3383            4.93s
#          6           1.3351            4.90s
#          7           1.3320            4.96s
#          8           1.3297            4.74s
#          9           1.3268            4.60s
#         10           1.3246            4.40s
#         20           1.3043            3.74s
#         30           1.2901            3.15s
#         40           1.2793            2.52s
#         50           1.2694            2.04s
#         60           1.2629            1.55s
#         70           1.2553            1.13s
#         80           1.2500            0.72s
#         90           1.2422            0.36s
#        100           1.2367            0.00s
# OneVsRestClassifier(estimator=GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_split=1e-07, min_samples_leaf=1,
#               min_samples_split=2, min_weight_fraction_leaf=0.0,
#               n_estimators=100, presort='auto', random_state=42,
#               subsample=1.0, verbose=1, warm_start=False),
#           n_jobs=1)

# %%
import sklearn.metrics as metrics

score = []
fpr = []
tpr = []
roc_auc = []

for i in range(len(countryList)):
    
    pred_val = clf.predict_proba(Xval)[:,i]
    #pred_val = clf.decision_function(Xval)[:,i]   ### WHICH ONE???
    yval_temp = (yval==i)
    f,t,_ = metrics.roc_curve(yval_temp,pred_val)

    auc = metrics.roc_auc_score(yval_temp,pred_val)
    
    fpr.append(f)
    tpr.append(t)
    roc_auc.append(auc)

print roc_auc
# Out:
# [0.57881375490422338, 0.57027890587673202, 0.52382920110192832, 0.51942380708551106, 0.60159706117358169, 0.56480487451037287, 0.58018395530255118, 0.60542837212251888, 0.31481481481481483, 0.61123543123543123]

# %%
## Plotting Multi-class ROC plot
fig, ax = plt.subplots(figsize = (8,8))
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], 
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))
    
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC value for each country of destination')
plt.legend(loc="lower right")
plt.show()

# %%
print(countryList)
# Out:
# ['AU', 'CA', 'DE', 'ES', 'FR', 'GB', 'IT', 'NL', 'PT', 'other']
